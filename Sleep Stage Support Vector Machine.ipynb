# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import mne

# %%
raw = mne.io.read_raw_edf('SC4001E0-PSG (2).edf')
annot = mne.read_annotations('SC4001EC-Hypnogram.edf')
raw.set_annotations(annot,emit_warning=False)
# Out:
# Extracting EDF parameters from C:\Users\HP\project\tutorial\SC4001E0-PSG (2).edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <RawEDF | SC4001E0-PSG (2).edf, 7 x 7950000 (79500.0 s), ~12 kB, data not loaded>

# %%
raw.plot(start=0,duration=30)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
data = raw.get_data()
df = pd.DataFrame(data)
df = df.transpose()
df
# Out:
#                 0             1         2           3         4          5  \
# 0        0.000005 -2.467399e-06  0.000017 -482.000000  0.000004  37.206452
# 1       -0.000003  1.467399e-06  0.000016 -477.513343  0.000004  37.206154
# 2        0.000001 -4.098901e-06  0.000010 -472.792126  0.000004  37.205865
# 3       -0.000002 -2.659341e-06  0.000002 -467.836265  0.000004  37.205584
# 4       -0.000005 -7.399267e-07  0.000008 -462.645805  0.000004  37.205314
# ...           ...           ...       ...         ...       ...        ...
# 7949995  0.000011 -6.882051e-06  0.000082  120.019895  0.000003  37.430325
# 7949996  0.000004 -8.609524e-06  0.000062  119.233020  0.000003  37.430079
# 7949997  0.000005 -3.043223e-06  0.000070  118.437162  0.000003  37.429827
# 7949998 -0.000005 -3.715018e-06  0.000081  117.632748  0.000003  37.429568
# 7949999  0.000007  1.755311e-06  0.000102  116.820213  0.000003  37.429303
#
#                   6
# 0        920.000000
# 1        919.251369
# 2        918.501596
# 3        917.751318
# 4        917.001168
# ...             ...
# 7949995  884.192595
# 7949996  883.955098
# 7949997  883.717035
# 7949998  883.478461
# 7949999  883.239431
#
# [7950000 rows x 7 columns]

# %%
annot_df = annot.to_data_frame()
annot_df
# Out:
#                   onset  duration    description
# 0   1970-01-01 00:00:00   30630.0  Sleep stage W
# 1   1970-01-01 08:30:30     120.0  Sleep stage 1
# 2   1970-01-01 08:32:30     390.0  Sleep stage 2
# 3   1970-01-01 08:39:00      30.0  Sleep stage 3
# 4   1970-01-01 08:39:30      30.0  Sleep stage 2
# ..                  ...       ...            ...
# 149 1970-01-01 14:19:00      30.0  Sleep stage 1
# 150 1970-01-01 14:19:30     540.0  Sleep stage W
# 151 1970-01-01 14:28:30     150.0  Sleep stage 1
# 152 1970-01-01 14:31:00   27240.0  Sleep stage W
# 153 1970-01-01 22:05:00    6900.0  Sleep stage ?
#
# [154 rows x 3 columns]

# %%
label = {'Sleep stage 1':1,'Sleep stage 2':2,'Sleep stage 3':3,'Sleep stage W':0,'Sleep stage 4':3,'Sleep stage R':4,'Sleep stage ?':-1,'Movement time':-1}
annot_df['description'] = annot_df['description'].replace(label)
annot_df
# Out:
#                   onset  duration  description
# 0   1970-01-01 00:00:00   30630.0            0
# 1   1970-01-01 08:30:30     120.0            1
# 2   1970-01-01 08:32:30     390.0            2
# 3   1970-01-01 08:39:00      30.0            3
# 4   1970-01-01 08:39:30      30.0            2
# ..                  ...       ...          ...
# 149 1970-01-01 14:19:00      30.0            1
# 150 1970-01-01 14:19:30     540.0            0
# 151 1970-01-01 14:28:30     150.0            1
# 152 1970-01-01 14:31:00   27240.0            0
# 153 1970-01-01 22:05:00    6900.0           -1
#
# [154 rows x 3 columns]

# %%
annot_df.groupby(['description']).sum()
# Out:
#              duration
# description
# -1             6900.0
#  0            59910.0
#  1             1740.0
#  2             7500.0
#  3             6600.0
#  4             3750.0

# %%
annot_list = []
for i in range(0,153):
    dur = int(annot_df.iloc[i,1])
    des = int(annot_df.iloc[i,2])
    for j in range(0,dur):
        annot_list.append(des)

# %%
cols = ['Stages']
annot_list = pd.DataFrame(annot_list,columns=cols)
annot_list
# Out:
#        Stages
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 79495       0
# 79496       0
# 79497       0
# 79498       0
# 79499       0
#
# [79500 rows x 1 columns]

# %%
df = df.iloc[0:79500]
df
# Out:
#               0             1         2           3         4          5  \
# 0      0.000005 -2.467399e-06  0.000017 -482.000000  0.000004  37.206452
# 1     -0.000003  1.467399e-06  0.000016 -477.513343  0.000004  37.206154
# 2      0.000001 -4.098901e-06  0.000010 -472.792126  0.000004  37.205865
# 3     -0.000002 -2.659341e-06  0.000002 -467.836265  0.000004  37.205584
# 4     -0.000005 -7.399267e-07  0.000008 -462.645805  0.000004  37.205314
# ...         ...           ...       ...         ...       ...        ...
# 79495  0.000033  1.068059e-05  0.000001  189.825492  0.000003  37.253137
# 79496  0.000067  9.145055e-06  0.000002  189.069777  0.000003  37.253041
# 79497  0.000025  7.993407e-06 -0.000031  188.308952  0.000003  37.252948
# 79498  0.000032  7.609524e-06 -0.000053  187.543434  0.000003  37.252859
# 79499  0.000014  5.210256e-06 -0.000060  186.773642  0.000003  37.252772
#
#                 6
# 0      920.000000
# 1      919.251369
# 2      918.501596
# 3      917.751318
# 4      917.001168
# ...           ...
# 79495  905.379169
# 79496  905.312811
# 79497  905.241653
# 79498  905.165756
# 79499  905.085184
#
# [79500 rows x 7 columns]

# %%
df_stats = df.describe()

# %%
df_stats = df_stats.transpose()

# %%
df_stats
# Out:
#      count          mean           std         min         25%           50%  \
# 0  79500.0  1.811138e-07  2.561919e-05   -0.000125   -0.000012  5.157509e-07
# 1  79500.0 -3.464879e-07  7.185456e-06   -0.000048   -0.000005 -4.520147e-07
# 2  79500.0  7.427894e-07  8.184781e-05   -0.000386   -0.000036 -2.463980e-07
# 3  79500.0  2.772545e+02  3.497052e+02 -907.900006  181.378693  2.211806e+02
# 4  79500.0  3.422791e-06  7.126552e-08    0.000003    0.000003  3.422624e-06
# 5  79500.0  3.721832e+01  2.517206e-02   37.143711   37.200739  3.721811e+01
# 6  79500.0  8.896052e+02  5.765405e+01   -2.770382  879.616700  8.935192e+02
#
#           75%          max
# 0    0.000013     0.000157
# 1    0.000004     0.000056
# 2    0.000035     0.000445
# 3  317.617642  2015.034675
# 4    0.000003     0.000004
# 5   37.235538    37.325715
# 6  907.264523  1021.897795

# %%
def norm(x):
    return (x - df_stats['mean']) / df_stats['std']

df = norm(df)

# %%
df
# Out:
#               0         1         2         3         4         5         6
# 0      0.188754 -0.295167  0.192624 -2.171127  1.813066 -0.471340  0.527193
# 1     -0.107727  0.252439  0.186603 -2.158298  1.834960 -0.483177  0.514208
# 2      0.046004 -0.522223  0.108332 -2.144797  1.856496 -0.494663  0.501203
# 3     -0.100406 -0.321880  0.011998 -2.130625  1.877656 -0.505789  0.488190
# 4     -0.210214 -0.054755  0.084248 -2.115783  1.898424 -0.516544  0.475179
# ...         ...       ...       ...       ...       ...       ...       ...
# 79495  1.283172  1.534638  0.005977 -0.250008  0.946352  1.383297  0.273597
# 79496  2.589885  1.320938  0.011998 -0.252169  0.930013  1.379503  0.272446
# 79497  0.975710  1.160663 -0.385380 -0.254344  0.913086  1.375822  0.271212
# 79498  1.250230  1.107238 -0.656320 -0.256533  0.895582  1.372258  0.269895
# 79499  0.558441  0.773332 -0.746633 -0.258735  0.877512  1.368810  0.268498
#
# [79500 rows x 7 columns]

# %%
X = df.iloc[20000:70000].values
Y = annot_list.iloc[20000:70000].values
print(X.shape)
print(Y.shape)
# Out:
# (50000, 7)
# (50000, 1)

# %%
from tensorflow.keras.utils import normalize,to_categorical

# %%
#Y = to_categorical(Y)

# %%
Y
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
from sklearn.svm import SVC
model_rbf = SVC(kernel = 'rbf')
model_poly = SVC(kernel = 'poly')
model_sigmoid = SVC(kernel = 'sigmoid')

# %%
model_rbf.fit(X_train,Y_train)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
model_poly.fit(X_train,Y_train)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
model_sigmoid.fit(X_train,Y_train)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='sigmoid')

# %%
Y_pred_rbf = model_rbf.predict(X_test)

# %%
Y_pred_poly = model_poly.predict(X_test)

# %%
Y_pred_sigmoid = model_sigmoid.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(Y_test, Y_pred_rbf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.96      0.86      7621
#            1       0.81      0.24      0.37       444
#            2       0.59      0.37      0.45      1834
#            3       0.58      0.57      0.58      1632
#            4       0.79      0.10      0.18       969
#
#     accuracy                           0.73     12500
#    macro avg       0.71      0.45      0.49     12500
# weighted avg       0.72      0.73      0.69     12500

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(Y_test, Y_pred_poly))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.99      0.78      7621
#            1       0.76      0.14      0.23       444
#            2       0.63      0.06      0.10      1834
#            3       0.71      0.14      0.23      1632
#            4       0.93      0.03      0.06       969
#
#     accuracy                           0.64     12500
#    macro avg       0.73      0.27      0.28     12500
# weighted avg       0.67      0.64      0.53     12500

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(Y_test, Y_pred_sigmoid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.75      0.65      7621
#            1       0.00      0.00      0.00       444
#            2       0.07      0.03      0.04      1834
#            3       0.04      0.03      0.03      1632
#            4       0.07      0.02      0.03       969
#
#     accuracy                           0.47     12500
#    macro avg       0.15      0.17      0.15     12500
# weighted avg       0.37      0.47      0.41     12500

# %%
from joblib import dump, load
dump(model_rbf, 'SleepSVM_RBF.joblib')
dump(model_poly, 'SleepSVM_POLY.joblib')
dump(model_sigmoid,'SleepSVM_SIGMOID.joblib')
# Out:
# ['SleepSVM_SIGMOID.joblib']
